# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('MMR World Bank Data.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     184 non-null    object
#  1   MMR         184 non-null    int64
#  2   MMR Rating  184 non-null    object
#  3   Column3     184 non-null    object
#  4   Column4     184 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 7.3+ KB

# %%
data.head()
# Out:
#        Country   MMR              MMR Rating           Column3      Column4
# 0      Algeria    78         Very Low (<100)    27.5231 3.1685      Algeria
# 1       Angola   222           Low (100-299)  -12.2916 17.5029       Angola
# 2      Burundi   494          High (300-499)    -3.407 29.8885      Burundi
# 3  Afghanistan   620     Very High (500-999)   34.4754 66.8303  Afghanistan
# 4      Nigeria  1047  Extremely High (>1000)     9.6551 8.1061      Nigeria

# %%
data.drop(['Column3', 'Column4'], inplace=True, axis=1)

# %%
data.head()
# Out:
#        Country   MMR              MMR Rating
# 0      Algeria    78         Very Low (<100)
# 1       Angola   222           Low (100-299)
# 2      Burundi   494          High (300-499)
# 3  Afghanistan   620     Very High (500-999)
# 4      Nigeria  1047  Extremely High (>1000)

# %%
legend = list(data.loc[:, 'MMR Rating'].unique())

# %%
legend
# Out:
# ['Very Low (<100)',
#  'Low (100-299)',
#  'High (300-499)',
#  'Very High (500-999)',
#  'Extremely High (>1000)']

# %%
bars = plt.barh(data.loc[:25, 'Country'], data.loc[:25, 'MMR'])
plt.xlabel('Maternal Mortality Rate')
# bars[20].set_color('red')
bars[0].set_color('#fbb4ae')
bars[1].set_color('#cefbae')
bars[2].set_color('#aef5fb')
bars[3].set_color('#daaefb')
bars[4].set_color('#513a38')
bars[5].set_color('#fbb4ae')
bars[6].set_color('#fbb4ae')
bars[7].set_color('#fbb4ae')
bars[8].set_color('#fbb4ae')
bars[9].set_color('#fbb4ae')
bars[10].set_color('#fbb4ae')
bars[11].set_color('#fbb4ae')
bars[12].set_color('#fbb4ae')
bars[13].set_color('#fbb4ae')
bars[14].set_color('#cefbae')
bars[15].set_color('#fbb4ae')
bars[16].set_color('#fbb4ae')
bars[17].set_color('#fbb4ae')
bars[18].set_color('#cefbae')
bars[19].set_color('#daaefb')
bars[20].set_color('#fbb4ae')
bars[21].set_color('#cefbae')
bars[22].set_color('#fbb4ae')
bars[23].set_color('#cefbae')
bars[24].set_color('#fbb4ae')
bars[25].set_color('#fbb4ae')
plt.ylabel('Country')
plt.grid(color="lightgray", alpha=0.25, zorder=1)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# Create Custom Legend
from matplotlib.lines import Line2D
legend_elements = [Line2D([0], [0], color='#fbb4ae', lw=4, label='Very Low (<100)'),
                   Line2D([0], [0], color='#cefbae', lw=4, label='Low (100-299)'),
                   Line2D([0], [0], color='#aef5fb', lw=4, label='High (300-499)'),
                   Line2D([0], [0], color='#daaefb', lw=4, label='Very High (500-999)'),
                   Line2D([0], [0], color='#513a38', lw=4, label='Extremely High (>1000)')
                   ]
plt.legend(handles=legend_elements, title='MMR Categories', fontsize=8, title_fontsize=8)

# plt.margins(0.0001)
plt.show()
